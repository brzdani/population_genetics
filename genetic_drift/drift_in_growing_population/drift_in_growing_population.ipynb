# %%
#basicc simulation with default values
K = 100 
R = 1.5
N = 10
GEN = 40
H = 0.5 

# %run drift_in_growing_population.py --GEN {GEN} --R {R} --K {K} --H {H} --N {N}

# %%
# decreasing r
K = 100 
R = 1.1
N = 10
GEN = 40
H = 0.5 

# %run drift_in_growing_population.py --GEN {GEN} --R {R} --K {K} --H {H} --N {N}

# %%
#increasing k 
K = 200
R = 1.5
N = 10
GEN = 40
H = 0.5 

# %run drift_in_growing_population.py --GEN {GEN} --R {R} --K {K} --H {H} --N {N}

# %%
# decreasing n 
K = 100
R = 1.5
N = 5
GEN = 40
H = 0.5 

# %run drift_in_growing_population.py --GEN {GEN} --R {R} --K {K} --H {H} --N {N}

# %%
# increasing n
K = 100
R = 1.5
N = 50
GEN = 40
H = 0.5 

# %run drift_in_growing_population.py --GEN {GEN} --R {R} --K {K} --H {H} --N {N}

# %%
INIT_P_A1   = 0.4
INIT_P_B1   = 0.6
REC_RATE    = 0.1
# %run stabilizing_simulation.py --pA1 {INIT_P_A1} --pB1 {INIT_P_B1} --rec_rate {REC_RATE}

# %%
INIT_P_A1   = 0.4
INIT_P_B1   = 0.6
REC_RATE    = 0.3
# %run stabilizing_simulation.py --pA1 {INIT_P_A1} --pB1 {INIT_P_B1} --rec_rate {REC_RATE}

# %%
INIT_P_A1   = 0.9
INIT_P_B1   = 0.3
REC_RATE    = 0.1
# %run stabilizing_simulation.py --pA1 {INIT_P_A1} --pB1 {INIT_P_B1} --rec_rate {REC_RATE}

# %%
INIT_P_A1   = 0.3
INIT_P_B1   = 0.9
REC_RATE    = 0.1
# %run stabilizing_simulation.py --pA1 {INIT_P_A1} --pB1 {INIT_P_B1} --rec_rate {REC_RATE}

# %%
INIT_P_A1   = 0.4
INIT_P_B1   = 0.4
REC_RATE    = 0.1
# %run stabilizing_simulation.py --pA1 {INIT_P_A1} --pB1 {INIT_P_B1} --rec_rate {REC_RATE}

# %%
INIT_P_A1   = 0.9
INIT_P_B1   = 0.1
REC_RATE    = 0.1
# %run stabilizing_simulation.py --pA1 {INIT_P_A1} --pB1 {INIT_P_B1} --rec_rate {REC_RATE}

# %%
INIT_P_A1   = 0.4
INIT_P_B1   = 0.6
REC_RATE    = 0.1
# %run stabilizing_simulation.py

# %%
INIT_P_A1   = 0.4
INIT_P_B1   = 0.6
REC_RATE    = 0.3
# %run stabilizing_simulation.py

# %%
INIT_P_A1   = 0.9
INIT_P_B1   = 0.3
REC_RATE    = 0.1
# %run stabilizing_simulation.py

# %%
INIT_P_A1   = 0.3
INIT_P_B1   = 0.9
REC_RATE    = 0.1
# %run stabilizing_simulation.py

# %%
INIT_P_A1   = 0.4
INIT_P_B1   = 0.4
REC_RATE    = 0.1
# %run stabilizing_simulation.py

# %%
INIT_P_A1   = 0.9
INIT_P_B1   = 0.1
REC_RATE    = 0.1
# %run stabilizing_simulation.py
